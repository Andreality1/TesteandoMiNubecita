# %%
#Como se puede hacer para procesar el concepto que me permite aprender a ser mas
#Detallado en la realidad como yo puedo organizar los procesos que me determinan
#Como sujeto.
#Que conceptos hacen que mi totalidad sea mas nueva
#Que rutas yo puedo setear con tal de emprender el conocimiento a un grado mas 
#Especifico.

#Que puedo desarrollar ahora mismo, como el concepto se puede hacer mas eficiente
#Que realidad yo puedo determinar como el contenido se produce
#El movimiento que me hace mas paradigmatico
#El component que me ayuda a emprender.

print('codigo')


design = 'Psychological code'

print(design)

print('componiendo mas partes')
# Out:
# codigo
# Psychological code
# componiendo mas partes

# %%
#Cosito es esto, como el componente de la mente se concibe.

#Realidad hecha materia, la propiedad que se quiere vivir, el concepto que
#se quiere analizar.

#Este presente, este movimiento, este precepto.
#Es estar creando codigo.
#Movimientos mas humanos.


#Como yo puedo sentir el factor psicologico.


#Este concepto vendria a ser:

#la realidad que se quiere pensar, el movimiento que produce materia.
#Como yo describo acciones

# %%
#Aqui le hacemos lo siguiente

# %% [markdown]
# ```
# Que estamos aprendiendo:
# We are learning how to deploy code around the concept of dots, in polinomials
# And how the behavior of these polinomials define the order of magnitute in
# grade, by it's power, and a coeficient capable to trace behaviors in the plane
# we are currently working and developeming, how stetics between the dots, and how it's capabilities define a new way to sintetize the now.
#
# how i can define the traces of the dots.
# ```
