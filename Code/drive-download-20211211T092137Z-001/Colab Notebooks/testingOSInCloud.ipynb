# %%
import os


string_variable = os.getcwd()

array_variable = os.listdir()

#Disfrutando del desarrollo intelectual de la vida de la mente.
#Aprendiendo como el saber se hace mas especifico, como yo puedo construir el 
#Como yo puedo determinar acciones las cuales emprender, como yo puedo
#procesar en la realidad las rutas que me determinan como identidad


#Es el que este tirando mas codigo mas rapido, el sujeto que sea capaz de tirar 
#mas lineas de codigo todo el tiempo.
print(array_variable)

os.chdir('/content/drive')

array_variable = os.listdir()

#Es lo que me este tirando codigo todo el tiempo
#A todo momento desplegando contenidos

os.chdir('/content/drive/MyDrive/ColabFolder/FolderMN')

array_variable = os.listdir()

#Como le meto al desarrollo interno que estamos aprendiendo como yo puedo 
#Situar todo el trabajo de la mente al grado mas amplificante




print(array_variable)

print(string_variable)
# Out:
# ['MyDrive', '.file-revisions-by-id', '.shortcut-targets-by-id', '.Trash-0']
# ['Codigo.py', 'MnImportModules.ipynb', 'Documento.ipynb']
# /content/drive
